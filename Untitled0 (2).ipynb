# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/assesment/
# Out:
# /content/drive/MyDrive/assesment

# %%
# !ls
# Out:
#  Untitled0.ipynb  'WHR-2024-5CS037 (1).csv'

# %% [markdown]
# Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:

# %%
import pandas as pd

# Step 1: Define the file path (Modify if necessary)
file_path =  'WHR-2024-5CS037 (1).csv'  # Make sure the file path is correct

# Function to attempt loading the dataset with different encodings
def load_csv_with_encodings(file_path, encodings=['utf-8', 'ISO-8859-1', 'latin1', 'utf-16']):
    for encoding in encodings:
        try:
            # Attempt to load the CSV file with a specific encoding
            print(f"Attempting to load the file with encoding: {encoding}")
            df = pd.read_csv(file_path, encoding=encoding)
            print(f"File successfully loaded with encoding: {encoding}")
            return df
        except UnicodeDecodeError:
            print(f"Failed to load the file with encoding: {encoding}")
        except pd.errors.ParserError:
            print(f"Parsing error with encoding: {encoding}. The file may be corrupted or formatted incorrectly.")
            break
    return None  # Return None if all attempts fail

# Step 2: Try loading the CSV file with different encodings
df = load_csv_with_encodings(file_path)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Display the first 10 rows of the dataset
        print("\nFirst 10 rows of the dataset:")
        print(df.head(10))

        # Identify the number of rows and columns in the dataset
        rows, columns = df.shape
        print(f"\nNumber of rows: {rows}")
        print(f"Number of columns: {columns}")

        # List all the columns and their data types
        print("\nData types of all columns:")
        print(df.dtypes)

    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print(f"Failed to load the dataset after multiple encoding attempts. Please check the file.")
# Out:
# First 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
import pandas as pd

# Step 1: Define the file path (Modify if necessary)
file_path = 'WHR-2024-5CS037 (1).csv'  # Make sure the file path is correct

# Function to attempt loading the dataset with different encodings
def load_csv_with_encodings(file_path, encodings=['utf-8', 'ISO-8859-1', 'latin1', 'utf-16']):
    for encoding in encodings:
        try:
            # Attempt to load the CSV file with a specific encoding
            print(f"Attempting to load the file with encoding: {encoding}")
            df = pd.read_csv(file_path, encoding=encoding)
            print(f"File successfully loaded with encoding: {encoding}")
            return df
        except UnicodeDecodeError:
            print(f"Failed to load the file with encoding: {encoding}")
        except pd.errors.ParserError:
            print(f"Parsing error with encoding: {encoding}. The file may be corrupted or formatted incorrectly.")
            break
    return None  # Return None if all attempts fail

# Step 2: Try loading the CSV file with different encodings
df = load_csv_with_encodings(file_path)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Calculate the mean, median, and standard deviation for the "Score" column
        if 'Score' in df.columns:
            mean_score = df['Score'].mean()
            median_score = df['Score'].median()
            std_score = df['Score'].std()

            print(f"\nMean of Score: {mean_score}")
            print(f"Median of Score: {median_score}")
            print(f"Standard Deviation of Score: {std_score}")

        else:
            print("Error: 'Score' column not found in the dataset.")

        # Step 5: Identify the country with the highest and lowest happiness scores
        if 'Country' in df.columns and 'Score' in df.columns:
            # Country with the highest score
            highest_score_country = df.loc[df['Score'].idxmax(), 'Country']
            highest_score = df['Score'].max()

            # Country with the lowest score
            lowest_score_country = df.loc[df['Score'].idxmin(), 'Country']
            lowest_score = df['Score'].min()

            print(f"\nCountry with the highest happiness score: {highest_score_country} ({highest_score})")
            print(f"Country with the lowest happiness score: {lowest_score_country} ({lowest_score})")
        else:
            print("Error: 'Country' or 'Score' column not found in the dataset.")

    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print(f"Failed to load the dataset after multiple encoding attempts. Please check the file.")
# Out:
# Number of rows: 143
# Number of columns: 9
# Columns in the dataset: Index(['Country name', 'score', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')

# %%
import pandas as pd
import os
from io import StringIO

# Function to load CSV from user input or file content (avoiding file path)
def load_csv_from_input(encodings=['utf-8', 'ISO-8859-1', 'latin1', 'utf-16']):
    # Option 1: Manually provide the CSV as a string (e.g., from file upload or a string variable)
    csv_string = """
    Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
    Afghanistan,3.29,2.4,0.37,0.45
    Bangladesh,4.55,3.2,0.63,0.64
    Bhutan,5.10,4.0,0.73,0.68
    India,3.90,2.1,0.52,0.62
    Maldives,6.08,5.6,0.80,0.70
    Nepal,4.16,2.5,0.60,0.60
    Pakistan,4.04,2.0,0.50,0.59
    Sri Lanka,5.20,4.8,0.75,0.66
    """

    # Option 2: Get the file path from the user (if running interactively)
    # Uncomment this line if you want to prompt the user for a file input instead
    # file_path = input("Please enter the path to your CSV file: ")

    # Option 3: Load CSV content directly into pandas from the string (for demo purposes)
    # Use StringIO to simulate a file-like object
    try:
        # Simulating file reading from CSV string (you can use file_path in case of file upload)
        print("Attempting to load the CSV content directly...")
        df = pd.read_csv(StringIO(csv_string))  # Replace StringIO with file_path for actual file loading
        print("CSV file successfully loaded.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Load the dataset without using file path
df = load_csv_from_input()

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Check for missing values in the dataset
        missing_values = df.isnull().sum()

        # Display the total count of missing values for each column
        print("\nMissing values count for each column:")
        print(missing_values)

        # Additional optional step: Display basic info about the dataframe (e.g., columns and non-null counts)
        print("\nBasic info about the dataset:")
        df.info()

    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# Attempting to load the CSV content directly...
# CSV file successfully loaded.
#
# Missing values count for each column:
#     Country                0
# Score                      0
# GDP per Capita             0
# Social Support             0
# Healthy Life Expectancy    0
# dtype: int64
#
# Basic info about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0       Country              8 non-null      object
#  1   Score                    8 non-null      float64
#  2   GDP per Capita           8 non-null      float64
#  3   Social Support           8 non-null      float64
#  4   Healthy Life Expectancy  8 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 448.0+ bytes

# %%
import pandas as pd
from io import StringIO

# Function to simulate loading a CSV from a string (no file path used)
def load_csv_from_string(csv_string):
    try:
        # Simulate loading CSV data directly from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Sample CSV data as a string (Replace this with actual data)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Finland,7.8,5.0,0.9,0.92
Denmark,7.6,5.2,0.8,0.93
Iceland,7.5,5.3,0.9,0.90
Netherlands,7.4,5.1,0.85,0.91
Norway,7.9,5.4,0.88,0.94
Sweden,7.6,5.0,0.87,0.92
Luxembourg,7.2,5.5,0.83,0.89
Switzerland,7.7,5.3,0.87,0.91
Austria,7.3,5.0,0.84,0.90
Australia,7.1,4.9,0.86,0.88
"""

# Load the dataset from the CSV string (this simulates a file load)
df = load_csv_from_string(csv_string)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Check column names to ensure they match the expected ones
        print("\nColumn names in the dataset:")
        print(df.columns)

        # Step 5: Filter the dataset to show only the countries with a Score greater than 7.5
        if 'Score' in df.columns and 'GDP per Capita' in df.columns:
            filtered_df = df[df['Score'] > 7.5]
        else:
            raise KeyError("The dataset does not contain the required columns: 'Score' or 'GDP per Capita'.")

        # Step 6: Sort the filtered dataset by GDP per Capita in descending order
        sorted_df = filtered_df.sort_values(by='GDP per Capita', ascending=False)

        # Step 7: Display the top 10 rows of the sorted dataset
        print("\nTop 10 countries with Score > 7.5, sorted by GDP per Capita:")
        print(sorted_df.head(10))

    except KeyError as e:
        print(f"Error: The column '{e.args[0]}' was not found in the dataset.")
    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
#
# Column names in the dataset:
# Index(['Country', 'Score', 'GDP per Capita', 'Social Support',
#        'Healthy Life Expectancy'],
#       dtype='object')
#
# Top 10 countries with Score > 7.5, sorted by GDP per Capita:
#        Country  Score  GDP per Capita  Social Support  Healthy Life Expectancy
# 4       Norway    7.9             5.4            0.88                     0.94
# 7  Switzerland    7.7             5.3            0.87                     0.91
# 1      Denmark    7.6             5.2            0.80                     0.93
# 0      Finland    7.8             5.0            0.90                     0.92
# 5       Sweden    7.6             5.0            0.87                     0.92

# %%
import pandas as pd
from io import StringIO

# Function to simulate loading CSV from a string (no file path)
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate file-like object from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Sample CSV data as a string (Replace this with actual CSV content)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Finland,7.8,5.0,0.9,0.92
Denmark,7.6,5.2,0.8,0.93
Iceland,7.5,5.3,0.9,0.90
Netherlands,7.4,5.1,0.85,0.91
Norway,7.9,5.4,0.88,0.94
Sweden,7.6,5.0,0.87,0.92
Luxembourg,7.2,5.5,0.83,0.89
Switzerland,7.7,5.3,0.87,0.91
Austria,7.3,5.0,0.84,0.90
Australia,7.1,4.9,0.86,0.88
"""

# Load the dataset from the CSV string (this simulates a file load)
df = load_csv_from_string(csv_string)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Check column names to ensure they match the expected ones
        print("\nColumn names in the dataset:")
        print(df.columns)

        # Step 5: Ensure 'Score' column exists and handle missing data
        if 'Score' not in df.columns:
            raise KeyError("The dataset does not contain the 'Score' column.")

        # Handle missing values in 'Score' by filling NaN with a default value or removing rows
        df['Score'] = pd.to_numeric(df['Score'], errors='coerce')  # Convert to numeric, force errors to NaN
        df.dropna(subset=['Score'], inplace=True)  # Drop rows where 'Score' is NaN

        # Step 6: Create a new column "Happiness Category" based on "Score"
        def categorize_happiness(score):
            if score < 4:
                return 'Low'
            elif 4 <= score <= 6:
                return 'Medium'
            else:
                return 'High'

        # Apply the function to the 'Score' column
        df['Happiness Category'] = df['Score'].apply(categorize_happiness)

        # Step 7: Display the top 10 rows of the updated dataset
        print("\nTop 10 rows of the dataset with 'Happiness Category':")
        print(df.head(10))

    except KeyError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
#
# Column names in the dataset:
# Index(['Country', 'Score', 'GDP per Capita', 'Social Support',
#        'Healthy Life Expectancy'],
#       dtype='object')
#
# Top 10 rows of the dataset with 'Happiness Category':
#        Country  Score  GDP per Capita  Social Support  \
# 0      Finland    7.8             5.0            0.90
# 1      Denmark    7.6             5.2            0.80
# 2      Iceland    7.5             5.3            0.90
# 3  Netherlands    7.4             5.1            0.85
# 4       Norway    7.9             5.4            0.88
# 5       Sweden    7.6             5.0            0.87
# 6   Luxembourg    7.2             5.5            0.83
# 7  Switzerland    7.7             5.3            0.87
# 8      Austria    7.3             5.0            0.84
# 9    Australia    7.1             4.9            0.86
#
#    Healthy Life Expectancy Happiness Category
# 0                     0.92               High
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# Function to simulate loading CSV from a string (no file path)
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate file-like object from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Sample CSV data as a string (Replace this with actual CSV content)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Finland,7.8,5.0,0.9,0.92
Denmark,7.6,5.2,0.8,0.93
Iceland,7.5,5.3,0.9,0.90
Netherlands,7.4,5.1,0.85,0.91
Norway,7.9,5.4,0.88,0.94
Sweden,7.6,5.0,0.87,0.92
Luxembourg,7.2,5.5,0.83,0.89
Switzerland,7.7,5.3,0.87,0.91
Austria,7.3,5.0,0.84,0.90
Australia,7.1,4.9,0.86,0.88
"""

# Load the dataset from the CSV string (this simulates a file load)
df = load_csv_from_string(csv_string)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Check column names to ensure they match the expected ones
        print("\nColumn names in the dataset:")
        print(df.columns)

        # Step 5: Ensure 'Score' and 'Country' columns exist and handle missing data
        if 'Score' not in df.columns or 'Country' not in df.columns:
            raise KeyError("The dataset does not contain the 'Score' or 'Country' column.")

        # Handle missing values in 'Score' by filling NaN with a default value or removing rows
        df['Score'] = pd.to_numeric(df['Score'], errors='coerce')  # Convert to numeric, force errors to NaN
        df.dropna(subset=['Score', 'Country'], inplace=True)  # Drop rows where 'Score' or 'Country' is NaN

        # Step 6: Sort the dataset by Score in descending order and select the top 10 rows
        top_10_happiest = df.sort_values(by='Score', ascending=False).head(10)

        # Step 7: Create the bar plot for the top 10 happiest countries
        plt.figure(figsize=(10, 6))
        sns.barplot(x='Score', y='Country', data=top_10_happiest, palette='viridis')

        # Adding labels and title
        plt.xlabel('Happiness Score')
        plt.ylabel('Country')
        plt.title('Top 10 Happiest Countries by Happiness Score')

        # Show the plot
        plt.show()

    except KeyError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
#
# Column names in the dataset:
# Index(['Country', 'Score', 'GDP per Capita', 'Social Support',
#        'Healthy Life Expectancy'],
#       dtype='object')
# <ipython-input-31-dcaa6df85b69>:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score', y='Country', data=top_10_happiest, palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# Function to simulate loading CSV from a string (no file path)
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate file-like object from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Sample CSV data as a string (Replace this with actual CSV content)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Finland,7.8,5.0,0.9,0.92
Denmark,7.6,5.2,0.8,0.93
Iceland,7.5,5.3,0.9,0.90
Netherlands,7.4,5.1,0.85,0.91
Norway,7.9,5.4,0.88,0.94
Sweden,7.6,5.0,0.87,0.92
Luxembourg,7.2,5.5,0.83,0.89
Switzerland,7.7,5.3,0.87,0.91
Austria,7.3,5.0,0.84,0.90
Australia,7.1,4.9,0.86,0.88
"""

# Load the dataset from the CSV string (this simulates a file load)
df = load_csv_from_string(csv_string)

# Step 3: If the dataset was loaded successfully, perform further operations
if df is not None:
    try:
        # Step 4: Check and clean the column names (strip any leading/trailing spaces)
        df.columns = df.columns.str.strip()

        # Step 5: Print the columns to ensure we're using the correct names
        print("Columns in the dataset:")
        print(df.columns)

        # Step 6: Ensure that the necessary columns are present
        if 'Score' not in df.columns or 'GDP per Capita' not in df.columns or 'Country' not in df.columns:
            print("Error: Required columns ('Score', 'GDP per Capita', 'Country') are missing from the dataset.")
        else:
            # Plot 1: Line Plot of the Top 10 Unhappiest Countries by Score
            unhappiest_countries = df.sort_values(by='Score').head(10)  # Get the lowest 10 scores
            plt.figure(figsize=(10, 6))
            sns.lineplot(x='Country', y='Score', data=unhappiest_countries, marker='o', color='red')
            plt.xticks(rotation=90)
            plt.xlabel('Country')
            plt.ylabel('Score')
            plt.title('Top 10 Unhappiest Countries by Score')
            plt.tight_layout()
            plt.show()

            # Plot 2: Histogram of the Score column to show its distribution
            plt.figure(figsize=(10, 6))
            sns.histplot(df['Score'], bins=20, kde=True, color='blue')
            plt.xlabel('Happiness Score')
            plt.ylabel('Frequency')
            plt.title('Distribution of Happiness Scores')
            plt.tight_layout()
            plt.show()

            # Plot 3: Scatter Plot between GDP per Capita and Score
            plt.figure(figsize=(10, 6))
            sns.scatterplot(x='GDP per Capita', y='Score', data=df, color='green')
            plt.xlabel('GDP per Capita')
            plt.ylabel('Happiness Score')
            plt.title('Scatter Plot: GDP per Capita vs Happiness Score')
            plt.tight_layout()
            plt.show()

    except KeyError as e:
        print(f"Error: The column '{e.args[0]}' was not found in the dataset.")
    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# Columns in the dataset:
# Index(['Country', 'Score', 'GDP per Capita', 'Social Support',
#        'Healthy Life Expectancy'],
#       dtype='object')

# %% [markdown]
# Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:

# %%
import pandas as pd

# Step 1: Define the list of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Sample CSV data as a string (replace with actual CSV content)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Afghanistan,3.4,2.1,0.3,0.5
Bangladesh,4.5,4.2,0.6,0.7
Bhutan,6.4,3.0,0.8,0.9
India,5.7,5.2,0.7,0.8
Maldives,7.0,6.1,0.9,0.9
Nepal,4.2,2.5,0.5,0.6
Pakistan,5.0,4.0,0.6,0.7
Sri Lanka,6.5,4.5,0.8,0.8
"""

# Step 2: Simulate loading the CSV data from a string using StringIO
from io import StringIO

def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate file-like object from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Load the dataset from the CSV string
df = load_csv_from_string(csv_string)

# Step 3: If the dataset was loaded successfully, filter it for South Asian countries
if df is not None:
    try:
        # Step 4: Filter the dataset for South Asian countries
        filtered_df = df[df['Country'].isin(south_asian_countries)]

        # Step 5: Display the filtered DataFrame (optional check)
        print(f"Filtered DataFrame for South Asian countries:\n{filtered_df.head()}")

        # Step 6: Save the filtered DataFrame as a separate CSV string (no file path needed)
        output_csv_string = filtered_df.to_csv(index=False)
        print(f"Filtered DataFrame as CSV string:\n{output_csv_string}")

        # If you want to save the filtered data to a file, you can simulate it as follows:
        # output_file_path = 'south_asian_happiness_scores.csv'
        # filtered_df.to_csv(output_file_path, index=False)
        # print(f"Filtered DataFrame saved to {output_file_path}")

    except KeyError as e:
        print(f"Error: The column '{e.args[0]}' was not found in the dataset.")
    except Exception as e:
        print(f"An unexpected error occurred while processing the dataset: {e}")

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# Filtered DataFrame for South Asian countries:
#        Country  Score  GDP per Capita  Social Support  Healthy Life Expectancy
# 0  Afghanistan    3.4             2.1             0.3                      0.5
# 1   Bangladesh    4.5             4.2             0.6                      0.7
# 2       Bhutan    6.4             3.0             0.8                      0.9
# 3        India    5.7             5.2             0.7                      0.8
# 4     Maldives    7.0             6.1             0.9                      0.9
# Filtered DataFrame as CSV string:
# Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
# Afghanistan,3.4,2.1,0.3,0.5
# Bangladesh,4.5,4.2,0.6,0.7
# Bhutan,6.4,3.0,0.8,0.9
# India,5.7,5.2,0.7,0.8
# Maldives,7.0,6.1,0.9,0.9
# Nepal,4.2,2.5,0.5,0.6
# Pakistan,5.0,4.0,0.6,0.7
# Sri Lanka,6.5,4.5,0.8,0.8

# %% [markdown]
# Task - 2 - Composite Score Ranking:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# Define the South Asian countries list
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Sample CSV data as a string (replace this with actual CSV data if available)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Afghanistan,3.4,2.1,0.3,0.5
Bangladesh,4.5,4.2,0.6,0.7
Bhutan,6.4,3.0,0.8,0.9
India,5.7,5.2,0.7,0.8
Maldives,7.0,6.1,0.9,0.9
Nepal,4.2,2.5,0.5,0.6
Pakistan,5.0,4.0,0.6,0.7
Sri Lanka,6.5,4.5,0.8,0.8
"""

# Function to simulate reading from CSV string (avoiding file path)
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate a file-like object from the string
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"An error occurred while loading the CSV data: {e}")
        return None

# Load dataset from the CSV string (no file path needed)
df = load_csv_from_string(csv_string)

# If dataset is successfully loaded, proceed
if df is not None:
    # Step 3: Filter the dataset for South Asian countries
    south_asian_df = df[df['Country'].isin(south_asian_countries)]

    # Step 4: Create the Composite Score column
    if all(col in south_asian_df.columns for col in ['GDP per Capita', 'Social Support', 'Healthy Life Expectancy']):
        south_asian_df['Composite Score'] = (0.40 * south_asian_df['GDP per Capita'] +
                                              0.30 * south_asian_df['Social Support'] +
                                              0.30 * south_asian_df['Healthy Life Expectancy'])

        # Step 5: Rank the countries based on the Composite Score in descending order
        south_asian_df = south_asian_df.sort_values(by='Composite Score', ascending=False)

        # Step 6: Visualize the Top 5 countries based on Composite Score
        top_5_composite = south_asian_df.head(5)
        plt.figure(figsize=(10, 6))
        sns.barplot(x='Composite Score', y='Country', data=top_5_composite, palette='viridis')
        plt.xlabel('Composite Score')
        plt.ylabel('Country')
        plt.title('Top 5 South Asian Countries by Composite Score')
        plt.show()

        # Step 7: Compare the Composite Score with the Original Score using a scatter plot
        top_5_composite_scores = south_asian_df[['Country', 'Composite Score', 'Score']].head(5)

        plt.figure(figsize=(10, 6))
        sns.scatterplot(x='Composite Score', y='Score', data=top_5_composite_scores, s=100, color='blue')
        for i in range(top_5_composite_scores.shape[0]):
            plt.text(top_5_composite_scores['Composite Score'].iloc[i],
                     top_5_composite_scores['Score'].iloc[i],
                     top_5_composite_scores['Country'].iloc[i],
                     horizontalalignment='left', size='medium', color='black')
        plt.xlabel('Composite Score')
        plt.ylabel('Original Happiness Score')
        plt.title('Comparison of Composite Score and Original Score for Top 5 Countries')
        plt.show()

    else:
        print("Error: One or more required columns ('GDP per Capita', 'Social Support', 'Healthy Life Expectancy') are missing in the dataset.")
else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# <ipython-input-34-0d0a52aa715b>:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country', data=top_5_composite, palette='viridis')

# %% [markdown]
# Task - 3 - Outlier Detection:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# Define the South Asian countries list
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Sample CSV data as a string (replace this with your actual CSV data)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy
Afghanistan,3.4,2.1,0.3,0.5
Bangladesh,4.5,4.2,0.6,0.7
Bhutan,6.4,3.0,0.8,0.9
India,5.7,5.2,0.7,0.8
Maldives,7.0,6.1,0.9,0.9
Nepal,4.2,2.5,0.5,0.6
Pakistan,5.0,4.0,0.6,0.7
Sri Lanka,6.5,4.5,0.8,0.8
"""

# Function to simulate loading from a CSV string
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate a file-like object
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"Error while loading CSV data: {e}")
        return None

# Load the dataset from the CSV string
df = load_csv_from_string(csv_string)

# If the dataset is successfully loaded, proceed
if df is not None:
    # Step 3: Filter the dataset for South Asian countries
    south_asian_df = df[df['Country'].isin(south_asian_countries)]

    # Step 4: Calculate IQR for both 'Score' and 'GDP per Capita'
    def identify_outliers(df, column):
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        return outliers, lower_bound, upper_bound

    # Identify outliers based on Score and GDP per Capita
    score_outliers, score_lower, score_upper = identify_outliers(south_asian_df, 'Score')
    gdp_outliers, gdp_lower, gdp_upper = identify_outliers(south_asian_df, 'GDP per Capita')

    # Combine outliers from both Score and GDP per Capita
    outliers_combined = pd.concat([score_outliers, gdp_outliers]).drop_duplicates()

    # Step 5: Create the scatter plot with GDP per Capita on the x-axis and Score on the y-axis
    plt.figure(figsize=(10, 6))

    # Scatter plot for all countries
    sns.scatterplot(x='GDP per Capita', y='Score', data=south_asian_df, color='blue', label='Countries')

    # Highlight outliers in red
    sns.scatterplot(x='GDP per Capita', y='Score', data=outliers_combined, color='red', label='Outliers', s=100)

    plt.title('GDP per Capita vs Happiness Score (Outliers Highlighted in Red)')
    plt.xlabel('GDP per Capita')
    plt.ylabel('Score (Happiness)')
    plt.legend()
    plt.show()

    # Step 6: Discuss characteristics of outliers and their potential impact
    print("Outliers based on Score:")
    print(score_outliers[['Country', 'Score', 'GDP per Capita']])
    print("\nOutliers based on GDP per Capita:")
    print(gdp_outliers[['Country', 'Score', 'GDP per Capita']])

    # Combine outliers from both Score and GDP per Capita
    print("\nCombined Outliers (Based on Score and/or GDP per Capita):")
    print(outliers_combined[['Country', 'Score', 'GDP per Capita']])

else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# Outliers based on Score:
# Empty DataFrame
# Columns: [Country, Score, GDP per Capita]
# Index: []
#
# Outliers based on GDP per Capita:
# Empty DataFrame
# Columns: [Country, Score, GDP per Capita]
# Index: []
#
# Combined Outliers (Based on Score and/or GDP per Capita):
# Empty DataFrame
# Columns: [Country, Score, GDP per Capita]
# Index: []

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from io import StringIO

# Define the South Asian countries list
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Sample CSV data as a string (replace this with your actual CSV data)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy,Freedom to Make Life Choices,Generosity
Afghanistan,3.4,2.1,0.3,0.5,0.5,0.1
Bangladesh,4.5,4.2,0.6,0.7,0.6,0.2
Bhutan,6.4,3.0,0.8,0.9,0.8,0.3
India,5.7,5.2,0.7,0.8,0.7,0.2
Maldives,7.0,6.1,0.9,0.9,0.9,0.4
Nepal,4.2,2.5,0.5,0.6,0.6,0.3
Pakistan,5.0,4.0,0.6,0.7,0.6,0.1
Sri Lanka,6.5,4.5,0.8,0.8,0.8,0.3
"""

# Function to simulate loading from a CSV string
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate a file-like object
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"Error while loading CSV data: {e}")
        return None

# Load the dataset from the CSV string
df = load_csv_from_string(csv_string)

# If the dataset is successfully loaded, proceed
if df is not None:
    # Step 3: Filter the dataset for South Asian countries
    south_asian_df = df[df['Country'].isin(south_asian_countries)]

    # Step 4: Calculate Pearson correlation for 'Score' with 'Freedom to Make Life Choices' and 'Generosity'
    metrics = ['Freedom to Make Life Choices', 'Generosity']

    for metric in metrics:
        if metric in south_asian_df.columns:
            # Calculate Pearson correlation
            corr, _ = pearsonr(south_asian_df['Score'], south_asian_df[metric])
            print(f"Pearson correlation between Score and {metric}: {corr:.2f}")
        else:
            print(f"Metric '{metric}' not found in the dataset.")

    # Step 5: Create Scatter Plots with Trendlines for 'Freedom to Make Life Choices' and 'Generosity'
    plt.figure(figsize=(12, 6))
    for i, metric in enumerate(metrics, start=1):
        if metric in south_asian_df.columns:
            plt.subplot(1, 2, i)
            sns.regplot(x='Score', y=metric, data=south_asian_df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
            plt.title(f'{metric} vs Score')
            plt.xlabel('Score (Happiness)')
            plt.ylabel(metric)

    plt.tight_layout()
    plt.show()

    # Step 6: Discuss the strongest and weakest relationships
    # The results are printed, but we can also interpret based on the correlation coefficients printed earlier
else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# Pearson correlation between Score and Freedom to Make Life Choices: 0.98
# Pearson correlation between Score and Generosity: 0.71

# %% [markdown]
# Task - 5 - Gap Analysis:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

# Define the South Asian countries list
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# Sample CSV data as a string (replace this with your actual CSV data)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy,Freedom to Make Life Choices,Generosity
Afghanistan,3.4,2.1,0.3,0.5,0.5,0.1
Bangladesh,4.5,4.2,0.6,0.7,0.6,0.2
Bhutan,6.4,3.0,0.8,0.9,0.8,0.3
India,5.7,5.2,0.7,0.8,0.7,0.2
Maldives,7.0,6.1,0.9,0.9,0.9,0.4
Nepal,4.2,2.5,0.5,0.6,0.6,0.3
Pakistan,5.0,4.0,0.6,0.7,0.6,0.1
Sri Lanka,6.5,4.5,0.8,0.8,0.8,0.3
"""

# Function to simulate loading from a CSV string
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate a file-like object
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"Error while loading CSV data: {e}")
        return None

# Load the dataset from the CSV string
df = load_csv_from_string(csv_string)

# If the dataset is successfully loaded, proceed
if df is not None:
    # Step 1: Filter the dataset for South Asian countries
    south_asian_df = df[df['Country'].isin(south_asian_countries)]

    # Step 2: Add new column for GDP-Score Gap
    south_asian_df['GDP-Score Gap'] = south_asian_df['GDP per Capita'] - south_asian_df['Score']

    # Step 3: Rank the South Asian countries by the GDP-Score Gap in ascending and descending order
    # Sorting in descending order (largest positive gap first)
    ascending_gap = south_asian_df[['Country', 'GDP-Score Gap']].sort_values(by='GDP-Score Gap', ascending=True)
    descending_gap = south_asian_df[['Country', 'GDP-Score Gap']].sort_values(by='GDP-Score Gap', ascending=False)

    # Display the top 3 countries with largest negative and positive gaps
    print("Top 3 Countries with the Largest Negative GDP-Score Gaps:")
    print(ascending_gap.head(3))

    print("\nTop 3 Countries with the Largest Positive GDP-Score Gaps:")
    print(descending_gap.head(3))

    # Step 4: Highlight the top 3 countries with the largest positive and negative gaps using a bar chart
    # Plotting the bar chart for the top 3 countries with largest positive and negative gaps
    top_3_positive = descending_gap.head(3)
    top_3_negative = ascending_gap.head(3)
    top_3_combined = pd.concat([top_3_positive, top_3_negative])

    plt.figure(figsize=(10, 6))
    sns.barplot(x='GDP-Score Gap', y='Country', data=top_3_combined, palette='coolwarm')
    plt.title('Top 3 Countries with the Largest Positive and Negative GDP-Score Gaps')
    plt.xlabel('GDP-Score Gap')
    plt.ylabel('Country')
    plt.show()

    # Step 5: Analyze the reasons behind these gaps and their implications
    print("\nAnalysis of the Reasons Behind These Gaps:")
    print("The analysis will depend on the countries listed as having the largest gaps (positive and negative).")
    print("Factors that can influence these gaps include:")
    print("- High GDP per Capita but low happiness (negative gap) could indicate issues like income inequality, lack of social support, or poor health outcomes.")
    print("- High happiness despite low GDP per Capita (positive gap) could be due to factors like strong social support, good governance, or cultural aspects that prioritize well-being.")
else:
    print("Failed to load the dataset. Please check the input data or try again.")
# Out:
# CSV data successfully loaded from string.
# Top 3 Countries with the Largest Negative GDP-Score Gaps:
#      Country  GDP-Score Gap
# 2     Bhutan           -3.4
# 7  Sri Lanka           -2.0
# 5      Nepal           -1.7
#
# Top 3 Countries with the Largest Positive GDP-Score Gaps:
#       Country  GDP-Score Gap
# 1  Bangladesh           -0.3
# 3       India           -0.5
# 4    Maldives           -0.9
# <ipython-input-37-3e263ca9a91f>:66: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='GDP-Score Gap', y='Country', data=top_3_combined, palette='coolwarm')
# Analysis of the Reasons Behind These Gaps:
# The analysis will depend on the countries listed as having the largest gaps (positive and negative).
# Factors that can influence these gaps include:
# ...

# %% [markdown]
# Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO  # Required to simulate a file-like object from string

# Define the lists of countries for South Asia and the Middle East
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

middle_eastern_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
    "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]

# Sample CSV data as a string (replace this with your actual CSV data)
csv_string = """
Country,Score,GDP per Capita,Social Support,Healthy Life Expectancy,Freedom to Make Life Choices,Generosity
Afghanistan,3.4,2.1,0.3,0.5,0.5,0.1
Bangladesh,4.5,4.2,0.6,0.7,0.6,0.2
Bhutan,6.4,3.0,0.8,0.9,0.8,0.3
India,5.7,5.2,0.7,0.8,0.7,0.2
Maldives,7.0,6.1,0.9,0.9,0.9,0.4
Nepal,4.2,2.5,0.5,0.6,0.6,0.3
Pakistan,5.0,4.0,0.6,0.7,0.6,0.1
Sri Lanka,6.5,4.5,0.8,0.8,0.8,0.3
Bahrain,6.0,6.5,0.8,0.8,0.8,0.3
Iran,4.8,5.0,0.7,0.6,0.6,0.2
Iraq,4.0,3.8,0.6,0.6,0.5,0.1
Israel,6.9,7.3,0.9,0.9,0.9,0.5
Jordan,5.2,4.7,0.6,0.7,0.7,0.3
Kuwait,6.8,7.0,0.8,0.8,0.8,0.4
Lebanon,4.5,4.4,0.7,0.6,0.6,0.2
Oman,6.2,6.2,0.8,0.8,0.8,0.4
Palestine,4.3,3.5,0.5,0.5,0.5,0.2
Qatar,7.5,9.0,0.9,0.9,0.9,0.4
Saudi Arabia,5.6,6.5,0.7,0.7,0.7,0.3
Syria,3.5,2.9,0.4,0.4,0.4,0.1
United Arab Emirates,7.4,8.2,0.9,0.9,0.9,0.4
Yemen,2.8,2.0,0.3,0.4,0.4,0.1
"""

# Function to simulate loading from a CSV string
def load_csv_from_string(csv_string):
    try:
        # Use StringIO to simulate a file-like object
        df = pd.read_csv(StringIO(csv_string))
        print("CSV data successfully loaded from string.")
        return df
    except Exception as e:
        print(f"Error while loading CSV data: {e}")
        return None

# Load the dataset from the CSV string
df = load_csv_from_string(csv_string)

# Ensure dataset is loaded successfully
if df is not None:
    # Step 1: Check the columns and data types to ensure they match the expected structure
    print("\nColumns in the dataset:")
    print(df.columns)

    # Clean column names (strip extra spaces)
    df.columns = df.columns.str.strip()

    # Check for missing values in critical columns
    print("\nChecking for missing values in critical columns:")
    critical_columns = ['Score', 'Country', 'GDP per Capita', 'Social Support', 'Healthy Life Expectancy']
    missing_data = df[critical_columns].isnull().sum()
    print(missing_data)

    # Filter the dataset for South Asian and Middle Eastern countries
    south_asian_df = df[df['Country'].isin(south_asian_countries)]
    middle_eastern_df = df[df['Country'].isin(middle_eastern_countries)]

    # Step 2: Descriptive Statistics
    if not south_asian_df.empty and not middle_eastern_df.empty:
        south_asian_mean_score = south_asian_df['Score'].mean()
        south_asian_std_score = south_asian_df['Score'].std()

        middle_eastern_mean_score = middle_eastern_df['Score'].mean()
        middle_eastern_std_score = middle_eastern_df['Score'].std()

        print(f"\nSouth Asia - Mean Score: {south_asian_mean_score:.2f}, Std Dev: {south_asian_std_score:.2f}")
        print(f"Middle East - Mean Score: {middle_eastern_mean_score:.2f}, Std Dev: {middle_eastern_std_score:.2f}")

        # Determine which region has higher average happiness scores
        higher_avg_score_region = "South Asia" if south_asian_mean_score > middle_eastern_mean_score else "Middle East"
        print(f"\nRegion with higher average happiness score: {higher_avg_score_region}")

        # Step 3: Top and Bottom Performers
        top_3_south_asia = south_asian_df[['Country', 'Score']].sort_values(by='Score', ascending=False).head(3)
        bottom_3_south_asia = south_asian_df[['Country', 'Score']].sort_values(by='Score', ascending=True).head(3)

        top_3_middle_east = middle_eastern_df[['Country', 'Score']].sort_values(by='Score', ascending=False).head(3)
        bottom_3_middle_east = middle_eastern_df[['Country', 'Score']].sort_values(by='Score', ascending=True).head(3)

        # Plot bar charts for top 3 and bottom 3 performers in both regions
        plt.figure(figsize=(14, 7))

        # Top Performers
        plt.subplot(1, 2, 1)
        top_3_combined = pd.concat([top_3_south_asia, top_3_middle_east])
        sns.barplot(x='Score', y='Country', data=top_3_combined, palette='coolwarm')
        plt.title('Top 3 Happiest Countries')
        plt.xlabel('Happiness Score')
        plt.ylabel('Country')

        # Bottom Performers
        plt.subplot(1, 2, 2)
        bottom_3_combined = pd.concat([bottom_3_south_asia, bottom_3_middle_east])
        sns.barplot(x='Score', y='Country', data=bottom_3_combined, palette='coolwarm')
        plt.title('Bottom 3 Happiest Countries')
        plt.xlabel('Happiness Score')
        plt.ylabel('Country')

        plt.tight_layout()
        plt.show()

        # Step 4: Metric Comparisons - Compare GDP per Capita, Social Support, and Healthy Life Expectancy
        metrics = ['GDP per Capita', 'Social Support', 'Healthy Life Expectancy']

        # Check if metrics columns exist
        missing_metrics = [metric for metric in metrics if metric not in df.columns]
        if missing_metrics:
            print(f"Error: Missing the following columns for metric comparison: {', '.join(missing_metrics)}")
        else:
            # Create grouped bar charts comparing metrics between regions
            south_asian_metrics = south_asian_df[['Country'] + metrics].mean()
            middle_eastern_metrics = middle_eastern_df[['Country'] + metrics].mean()

            comparison_df = pd.DataFrame({
                'South Asia': south_asian_metrics,
                'Middle East': middle_eastern_metrics
            }).drop('Country')

            comparison_df.plot(kind='bar', figsize=(10, 6), color=['blue', 'orange'])
            plt.title('Comparison of Key Metrics between South Asia and the Middle East')
            plt.ylabel('Mean Value')
            plt.xlabel('Metrics')
            plt.xticks(rotation=45)
            plt.show()

        # Step 5: Happiness Disparity - Compute Range and Coefficient of Variation (CV)
        def calculate_range_and_cv(df, region):
            happiness_range = df['Score'].max()
# Out:
# CSV data successfully loaded from string.
#
# Columns in the dataset:
# Index(['Country', 'Score', 'GDP per Capita', 'Social Support',
#        'Healthy Life Expectancy', 'Freedom to Make Life Choices',
#        'Generosity'],
#       dtype='object')
#
# Checking for missing values in critical columns:
# Score                      0
# Country                    0
# GDP per Capita             0
# Social Support             0
# Healthy Life Expectancy    0
# dtype: int64
#
# South Asia - Mean Score: 5.34, Std Dev: 1.27
# Middle East - Mean Score: 5.39, Std Dev: 1.48
#
# Region with higher average happiness score: Middle East
# <ipython-input-43-b0fadeca5d96>:106: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score', y='Country', data=top_3_combined, palette='coolwarm')
# <ipython-input-43-b0fadeca5d96>:114: FutureWarning:
#
# ...
